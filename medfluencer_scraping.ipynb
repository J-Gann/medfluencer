# %% [markdown]
# # Medlfuencer Scraping

# %% [markdown]
# ## Setup

# %%
# !wget http://archive.ubuntu.com/ubuntu/pool/main/libu/libu2f-host/libu2f-udev_1.1.4-1_all.deb
# !dpkg -i libu2f-udev_1.1.4-1_all.deb
# !wget https://dl.google.com/linux/direct/google-chrome-stable_current_amd64.deb
# !dpkg -i google-chrome-stable_current_amd64.deb

# !wget -N https://edgedl.me.gvt1.com/edgedl/chrome/chrome-for-testing/118.0.5993.70/linux64/chromedriver-linux64.zip -P /tmp/
# !unzip -o /tmp/chromedriver-linux64.zip -d /tmp/
# !unzip -o /tmp/chromedriver-linux64.zip -d /tmp/
# !mv /tmp/chromedriver-linux64/chromedriver /usr/local/bin/chromedriver
# %pip install selenium chromedriver_autoinstaller

# %%
import sys

sys.path.insert(0, "/usr/lib/chromium-browser/chromedriver")
from selenium import webdriver
import chromedriver_autoinstaller

# %% [markdown]
# ## Scraping

# %%
import json
from tqdm.auto import tqdm
import requests
import os
from selenium.webdriver.common.by import By
import json
from selenium.webdriver.common.by import By
from selenium import webdriver
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import requests
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import time
from dotenv import load_dotenv
import os
from itertools import islice
from youtube_comment_downloader import YoutubeCommentDownloader, SORT_BY_POPULAR


class bcolors:
    HEADER = "\033[95m"
    OKBLUE = "\033[94m"
    OKCYAN = "\033[96m"
    OKGREEN = "\033[92m"
    WARNING = "\033[93m"
    FAIL = "\033[91m"
    ENDC = "\033[0m"
    BOLD = "\033[1m"
    UNDERLINE = "\033[4m"


class Scraping:
    """Class for managing the YouTube scraping"""

    def __init__(self):
        load_dotenv()

        self.yt_api_key = os.getenv("YT_API_KEY")

        print(
            f"> Using YouTube API key: {bcolors.OKCYAN}{self.yt_api_key[:10]}...{bcolors.ENDC}"
        )

        self.channels = {}
        self.videos = {}
        self.comments = {}
        self.playlists = {}

    def save_json(self, path="scraping"):
        channels_file = open(os.path.join(path, "channels_scraping.json"), "w")
        json.dump(self.channels, channels_file)
        channels_file.close()

        videos_file = open(os.path.join(path, "videos_scraping.json"), "w")
        json.dump(self.videos, videos_file)
        videos_file.close()

        comments_file = open(os.path.join(path, "comments_scraping.json"), "w")
        json.dump(self.comments, comments_file)
        comments_file.close()

        playlists_file = open(os.path.join(path, "playlists_scraping.json"), "w")
        json.dump(self.playlists, playlists_file)
        playlists_file.close()

    def load_json(self, path="scraping"):
        channels_file = open(os.path.join(path, "channels_scraping.json"), "r")
        self.channels = json.load(channels_file)
        channels_file.close()

        videos_file = open(os.path.join(path, "videos_scraping.json"), "r")
        self.videos = json.load(videos_file)
        videos_file.close()

        comments_file = open(os.path.join(path, "comments_scraping.json"), "r")
        self.comments = json.load(comments_file)
        comments_file.close()

        playlists_file = open(os.path.join(path, "playlists_scraping.json"), "r")
        self.playlists = json.load(playlists_file)
        playlists_file.close()

    def _get_videos_without_metadata(self):
        ids = []
        for video_id in self.videos:
            if "title" not in self.videos[video_id]:
                ids.append(video_id)
            if "description" not in self.videos[video_id]:
                ids.append(video_id)
            if "tags" not in self.videos[video_id]:
                ids.append(video_id)
        return ids

    def _get_videos_without_transcription(self):
        ids = []
        for video_id in self.videos:
            if "transcription" not in self.videos[video_id]:
                ids.append(video_id)
        return ids

    def _get_channels_without_playlist(self):
        names = []
        for name in self.channels:
            if name not in self.playlists:
                names.append(name)
        return names

    def _get_videos_without_comments(self):
        videos_with_comments = []
        for comment_id, comment in self.comments.items():
            video_id = comment["video_id"]
            if video_id not in videos_with_comments:
                videos_with_comments.append(video_id)

        videos_without_comments = []
        for video_id in self.videos:
            if video_id not in videos_with_comments:
                if "no_comments" in self.videos[video_id]:
                    continue
                videos_without_comments.append(video_id)
        return videos_without_comments

    def print_status(self):

        missing_transcription = self._get_videos_without_transcription()
        missing_playlists = self._get_channels_without_playlist()
        missing_comments = self._get_videos_without_comments()
        missing_metadata = self._get_videos_without_metadata()

        out = f"""
        Scraping overview
        -----------------

        Current number of channels:\t{len(self.channels)}
        Current number of videos:\t{len(self.videos)}
        Current number of comments:\t{len(self.comments)}

        ----

        Current number of unscraped playlist:\t{len(missing_playlists)}
        Current number of videos with missing transcription:\t{len(missing_transcription)}
        Current number of videos without comments:\t{len(missing_comments)}
        Current number of videos without metadata:\t{len(missing_metadata)}
        """
        print(out)

    def load_channels(
        self,
        path="./medfluencer_channel_names.json",
    ):
        """Load all channel names which should be scraped"""
        with open(path, encoding="utf-8") as f:
            channel_names = json.load(f)
            for channel_name in channel_names:
                if channel_name not in self.channels:
                    self.channels[channel_name] = {
                        "id": None,
                        "playlist_id": None,
                        "description": None,
                    }
        self.save_json()

        self.load_channel_info()

    def load_channel_info(self):
        """Load metadata of channel"""
        print(
            f"> Querying channel ids from YouTube Data API ({bcolors.WARNING}Warning: cost=1/channel{bcolors.ENDC})"
        )
        cost = 0
        for channel_name in tqdm(list(self.channels.keys())):
            if (
                self.channels[channel_name]["id"] is not None
                and self.channels[channel_name]["playlist_id"] is not None
                and self.channels[channel_name]["description"] is not None
            ):
                continue

            cost += 1
            base_url = "https://www.googleapis.com/youtube/v3/channels"
            params = {
                "key": self.yt_api_key,
                "forHandle": channel_name,
                "part": "id, snippet, contentDetails",
            }
            response = requests.get(base_url, params=params, timeout=10)
            response = response.json()

            if "items" not in response:
                continue

            item = response["items"][0]
            channel_id = item["id"]
            description = item["snippet"]["description"]
            playlist_id = item["contentDetails"]["relatedPlaylists"]["uploads"]

            self.channels[channel_name] = {
                "id": channel_id,
                "playlist_id": playlist_id,
                "description": description,
            }

        self.save_json()

    def get_videos_from_upload_playlist(self):
        """
        Retrieve video IDs from upload playlists for all channels.
        """
        print(
            f"> Querying video ids from upload playlists from YouTube Data API ({bcolors.WARNING}Warning: cost=1/channel{bcolors.ENDC})"
        )

        for channel_name, channel in tqdm(self.channels.items()):
            if not channel["playlist_id"]:
                continue

            if channel_name in self.playlists:
                continue

            base_url = "https://www.googleapis.com/youtube/v3/playlistItems"
            params = {
                "key": self.yt_api_key,
                "playlistId": channel["playlist_id"],
                "part": "contentDetails",
                "maxResults": 50,
            }

            next_page_token = None
            while True:
                if next_page_token:
                    params["pageToken"] = next_page_token

                response = requests.get(base_url, params=params, timeout=10)

                response = response.json()

                if "items" not in response:
                    break

                self.playlists[channel_name] = []

                for video in response["items"]:

                    video_id = video["contentDetails"]["videoId"]

                    self.playlists[channel_name].append(video_id)

                    if video_id not in self.videos:
                        self.videos[video_id] = {
                            "channel_name": channel_name,
                            "description": None,
                            "transcription": None,
                        }

                if "nextPageToken" in response:
                    next_page_token = response["nextPageToken"]
                else:
                    break
        self.save_json()

    def get_video_infos(self):
        """
        Retrieve additional metadata of videos
        """
        print(
            f"> Querying video ids from upload playlists from YouTube Data API ({bcolors.WARNING}Warning: cost=1/channel{bcolors.ENDC})"
        )

        video_ids = self._get_videos_without_metadata()
        batches = [video_ids[i : i + 50] for i in range(0, len(video_ids), 50)]

        for batch in tqdm(batches):
            time.sleep(0.1)
            base_url = "https://www.googleapis.com/youtube/v3/videos"
            params = {
                "key": self.yt_api_key,
                "id": ",".join(batch),
                "part": "snippet",
                "maxResults": 50,
            }

            response = requests.get(base_url, params=params, timeout=10)
            response = response.json()

            if "items" not in response:
                break

            for item in response["items"]:

                video_id = item["id"]

                snippet = item["snippet"]

                title = snippet["title"]

                if "description" in snippet:
                    description = snippet["description"]
                else:
                    description = ""

                if "tags" in snippet:
                    tags = snippet["tags"]
                else:
                    tags = []

                self.videos[video_id]["title"] = title
                self.videos[video_id]["description"] = description
                self.videos[video_id]["tags"] = tags

        self.save_json()

    def get_driver(self):

        capabilities = DesiredCapabilities.CHROME
        capabilities["goog:loggingPrefs"] = {"performance": "ALL"}

        chrome_options = webdriver.ChromeOptions()
        chrome_options.add_argument("--no-sandbox")
        chrome_options.add_argument("--disable-dev-shm-usage")
        chromedriver_autoinstaller.install()

        driver = webdriver.Chrome(options=chrome_options)

        return driver

    def get_video_captions_scraped(self, driver):

        videos_without_transcription = self._get_videos_without_transcription()

        for video_id in tqdm(videos_without_transcription):

            video = self.videos[video_id]

            if video["transcription"] is not None:
                continue

            try:
                driver.get(f"https://www.youtube.com/watch?v={video_id}")

                driver.find_element(By.CLASS_NAME, "ytp-subtitles-button").click()

                logs = driver.get_log("performance")
                relevant_logs = []
                for log in logs:
                    if "timedtext" in str(log):
                        relevant_logs.append(log)

                transcription_found = False
                for log in relevant_logs:
                    if video_id in str(log) and '"Network.requestWillBeSent"' in str(
                        log
                    ):
                        url = json.loads(log["message"])["message"]["params"][
                            "request"
                        ]["url"]
                        if video_id in url:
                            res = requests.get(url, timeout=10)
                            data = res.content.decode("utf-8")
                            data = json.loads(data)
                            text = ""
                            for elem in data["events"]:
                                if "segs" in elem.keys():
                                    for seg in elem["segs"]:
                                        text += seg["utf8"]
                            video["transcription"] = text
                            tqdm.write(f"{video_id}: {repr(text[:50])} ...")
                            transcription_found = True
                            break
                if not transcription_found:
                    tqdm.write(f"{video_id}: No transcription found.")
            except Exception as e:
                tqdm.write(f"{video_id}: Error occured while retrieving transcription.")
        self.save_json()

    def get_comments_for_video(self):
        """
        Retrieve video IDs from upload playlists for all channels.
        """
        print(
            f"> Querying video ids from upload playlists from YouTube Data API ({bcolors.WARNING}Warning: cost=1/video{bcolors.ENDC})"
        )

        videos_without_comments = self._get_videos_without_comments()

        for video_id in tqdm(videos_without_comments):
            base_url = (
                "https://content-youtube.googleapis.com/youtube/v3/commentThreads"
            )

            params = {
                "key": self.yt_api_key,
                "videoId": video_id,
                "part": "snippet, replies",
                "maxResults": 100,
            }

            next_page_token = None
            while True:
                time.sleep(0.1)
                if next_page_token:
                    params["pageToken"] = next_page_token

                response = requests.get(base_url, params=params, timeout=10)

                response = response.json()

                if "items" not in response:
                    break

                if len(response["items"]) == 0:
                    self.videos[video_id]["no_comments"] = True

                for comment in response["items"]:

                    comment_id = comment["snippet"]["topLevelComment"]["id"]
                    text = comment["snippet"]["topLevelComment"]["snippet"][
                        "textDisplay"
                    ]
                    author_display_name = comment["snippet"]["topLevelComment"][
                        "snippet"
                    ]["authorDisplayName"]

                    replies = []

                    if "replies" in comment:
                        for reply in comment["replies"]["comments"]:
                            replies.append(reply["snippet"]["textDisplay"])

                    self.comments[comment_id] = {
                        "text": text,
                        "authorDisplayName": author_display_name,
                        "video_id": video_id,
                        "replies": replies,
                    }

                    tqdm.write(f"{video_id}: {text[:50]}")

                # if "nextPageToken" in response:
                #    next_page_token = response["nextPageToken"]    # only use first 50 comments
                # else:
                #    break
                break
        self.save_json()

    def get_comments_for_video_scraped(self):
        print(
            f"> Querying video ids from upload playlists from YouTube Data API ({bcolors.WARNING}Warning: cost=1/video{bcolors.ENDC})"
        )

        downloader = YoutubeCommentDownloader()

        videos_without_comments = self._get_videos_without_comments()

        for video_id in tqdm(videos_without_comments):

            comments = downloader.get_comments_from_url(
                f"https://www.youtube.com/watch?v={video_id}",
                sort_by=SORT_BY_POPULAR,
            )

            no_comments = True
            for comment in islice(comments, 100):
                no_comments = False
                self.comments[comment["cid"]] = {
                    "text": comment["text"],
                    "authorDisplayName": comment["author"],
                    "video_id": video_id,
                    "replies": [],  # unable to get replies, possible to do manually later
                }
                tqdm.write(f"{video_id}: {comment['text'][:50]}")

            if no_comments:
                self.videos[video_id]["no_comments"] = True


scraping = Scraping()
scraping.load_json()
# Out:
# > Using YouTube API key: AIzaSyAf09...

# %%
scraping.print_status()
# Out:
#         Scraping overview
#         -----------------
#
#         Current number of channels:	362
#         Current number of videos:	94422
#         Current number of comments:	998721
#
#         ----
#
#         Current number of unscraped playlist:	13
#         Current number of videos with missing transcription:	9440
#         Current number of videos without comments:	0

# %%
scraping.load_channels()

# %%
scraping.get_videos_from_upload_playlist()

# %%
driver = scraping.get_driver()

# %%
scraping.get_video_captions_scraped(driver)

# %%
scraping.save_json("scraping")

# %%
scraping.get_comments_for_video_scraped()
# Out:
# > Querying video ids from upload playlists from YouTube Data API (Warning: cost=1/video)
#   0%|          | 0/13155 [00:00<?, ?it/s]
# nhSeT4WrGX0: es gibt zig tausende kliniken. woher willst du wis
# nhSeT4WrGX0: Bruder fahr dein Bett hoch
# nhSeT4WrGX0: He is cute 🥰
# sZAyj8Byr-U: 💞💞💞☺☺☺✌✌✌😘😘
# sZAyj8Byr-U: Hallo
# dW2wkrWCpHY: Uhh voll der süße boooyy
#
# Gruß angelo merte 007
# dW2wkrWCpHY: Die Beschreibung unter dem video ist falsch!!!
# dW2wkrWCpHY: lappen
# dW2wkrWCpHY: Omg wie unsympathisch ist der.
# dW2wkrWCpHY: +nico herm. Vielen Dank für den Hinweis, wir haben
# QTq0_YpOpPA: Da bin ich jahrelang in die Schule gegangen und er
# QTq0_YpOpPA: Boah voll die schöne Frau ❤
# QTq0_YpOpPA: 👍
# QTq0_YpOpPA: Ja Danke!!! Bist ein super Kumunikator deutlich er
# QTq0_YpOpPA: Danke für diesen Beitrag, der so ziemlich 1:1 eine
# QTq0_YpOpPA: Ähnlich wie Borderline, mich würde der Unterschied
# QTq0_YpOpPA: Ich bin gerade verwirrt. Das bedeutet dass alle Me
# QTq0_YpOpPA: Schlimm! 😮
# QTq0_YpOpPA: Ganz schön harte tobak und /aber grausam wenn ihm
# gNZ0TQ9U8VA: Da muss man, dann aber auch eine gute Kritikfähigk
# gNZ0TQ9U8VA: Danke für die Einführung in das Thema! Was für ein
# gNZ0TQ9U8VA: Herzlichen Dank, wünsch einen schönen Sonntag.
# Au
# gNZ0TQ9U8VA: Danke für dieses hilfreiche Video zur Zwiegespräch
# gNZ0TQ9U8VA: Ich trage schon fast ein halbes Jahr viele Unsiche
# gNZ0TQ9U8VA: 🍀🙂
# gNZ0TQ9U8VA: Meine Partnerin kann längeren (ab ca. 20 sec) Blic
# gNZ0TQ9U8VA: Liebe Saskia,
#
# ja genau, Kritik bzw. Wünsche/Wahr
# gNZ0TQ9U8VA:  @DrMichaelaKrohn  Hallo liebe Michaela, gut erklä
# gNZ0TQ9U8VA: Sich als Paar bei solchen Dingen unterstützen zu l
# gNZ0TQ9U8VA:  @DrMichaelaKrohn  In einer Reha früher, gab es so
# gNZ0TQ9U8VA: 😊Danke, wünsche ich dir auch 🌞
# gNZ0TQ9U8VA: Vielen Dank, das freut mich😀
# gNZ0TQ9U8VA: Ja, es ist auch schwierig, wenn man jemand ist, de
# gNZ0TQ9U8VA: Guten Morgen liebe Saskia, danke für's Schauen 😀🙏💫
# gNZ0TQ9U8VA: ​ @DrMichaelaKrohn So gerne!😀🍀
# v42GLLTe-Jw: Danke. ⚖️✨❤
# v42GLLTe-Jw: Welch' ein schöner Satz , liebe Michaela:, den Du
# v42GLLTe-Jw: Wieder gutes Video :)
# v42GLLTe-Jw: Richtig, die ÄVPS von Jochen ist nicht die selbe Ä
# v42GLLTe-Jw: Danke dir!!! Und danke euch allen für's immer wied
# v42GLLTe-Jw: ​ @DrMichaelaKrohn Möchte mich auch bedanken, wied
# v42GLLTe-Jw: @saskia5265 vielen lieben Dank!!!❤❤❤😃🙏
# v42GLLTe-Jw:  @DrMichaelaKrohn  🙏🙂❤️🍀!!!
# v42GLLTe-Jw: Liebe Andrea - definitiv eine Lebensaufgabe😅... di
# v42GLLTe-Jw: Mega! Danke dir sehr!!!😃🙏❤🌠😊
# v42GLLTe-Jw:  @DrMichaelaKrohn  ich danke Ihnen 😊
# tI_h69h6Nrc: Interessanter Ansatz, Konflikte als Chance zur Sel
# tI_h69h6Nrc: Ich schau Ihren Kanal gerne, weil Sie oft Themen b
# tI_h69h6Nrc: Als Arbeitssoziologin sehe ich das ganze natürlich
# tI_h69h6Nrc: Sich nicht verstanden fühlen,  würde mich sehr fre
# ojGTy2JLpFs: Absolut. Wichtig ist, dass wir unsere Symptome sel
# an3-tzGDI4c: Sie sprechen mir mit diesem Video aus der Seele. A
# an3-tzGDI4c: Ich habe heute 4 Stunden gebraucht erst beim Arzt
# an3-tzGDI4c: Das Video is grad einfach Balsam. Danke
# an3-tzGDI4c: Als Altenpfleger ist es so wen ich krank bin kann
# an3-tzGDI4c: Ich verstehe die Frage nicht!
# an3-tzGDI4c: Deutschland ist Krank
# an3-tzGDI4c: Bei mir ist die Existenzangst..eben weil ich so ei
# an3-tzGDI4c: Leider wahr. Und dennoch ist die Aufgabe, in dem j
# an3-tzGDI4c: Gibst du vielleicht couching ich bin am Limit und
# an3-tzGDI4c: Ich verschleppe es schon ein Jahr und es wurde imm
# an3-tzGDI4c: Liebe Maria, na klar können wir das alles besprech
# s1aUyOUOgu8: Ich freue mich schon ❤
# s1aUyOUOgu8: Ich mich auch!!!😃❤️💫
# cKndD8RZ1dM: Hallo liebe Michaela, schön wieder ein Video von d
# cKndD8RZ1dM: Tolles Video. Erkenne mich wieder❤ Dankeschön!
# cKndD8RZ1dM: tausend Dank... genau mein Thema 😮 Ich kann  wohl
# cKndD8RZ1dM: Sehr cooles Video!
#
# Ich hab dieses extreme Selbst
# cKndD8RZ1dM: Wieder tolles Video…Danke
# cKndD8RZ1dM: Könnten Sie etwas zum Thema generalisierte Angstst
# cKndD8RZ1dM: Liebe Saskia, danke für deinen Kommentar. Darin li
# cKndD8RZ1dM:  @DrMichaelaKrohn  Danke dir sehr. 😊🍀☀️💫❤️
# cKndD8RZ1dM: Vielen herzlichen Dank fürs Teilen hier. Es ist wi
# cKndD8RZ1dM: Vielen lieben Dank❤🙏
# cKndD8RZ1dM: Wollte ich eh schon länger was dazu machen. Ist no
# F0OlxeVA4ok: Ich habe ein Selbstbewusstsein wie ein Knäckebrot
# F0OlxeVA4ok: Das mit der toxischen Scham und den dadurch entste
# F0OlxeVA4ok: Ich danke dir so sehr, dass du die Videos machst!
# F0OlxeVA4ok: Dankeschön!!!
# F0OlxeVA4ok: Scham - das schlimmste Gefühl von allen.
# F0OlxeVA4ok: Genial
# F0OlxeVA4ok: 🎉
# F0OlxeVA4ok: Warum immer die Eltern? Bei mir wars jahrelanges M
# F0OlxeVA4ok: Vielen herzlichen Dank❤🙏
# F0OlxeVA4ok: Danke!!! Das freut mich sehr ❤🙏
# F0OlxeVA4ok: 🌞
# F0OlxeVA4ok: Und haben dich deine Eltern geschützt? Sind Sie ei
# ivxqpKtPLKY: Ja danke, ich für meinen Teil weiß das auf jeden F
# ivxqpKtPLKY:  @michaelakrohn5883  🙏❤️🍀
# o_3c78nwPl0: Ich glaube, ich habe mich selten so in einer Besch
# o_3c78nwPl0: Ich glaube das nach freez fawn Response kommt. Bei
# o_3c78nwPl0: Danke für die Aufklärung. Es scheint fast unmöglic
# o_3c78nwPl0: Endlich erklärt mir mal jemand warum ich das immer
# o_3c78nwPl0: Endlich mal das richtige Wort. Ich habe für mich a
# o_3c78nwPl0: Hier das Verständnis gefunden, das mir im anderen
# o_3c78nwPl0: 🍀
# o_3c78nwPl0: Leute die immer lieb und gutgelaunt sind...sowas v
# o_3c78nwPl0: Vielen lieben Dank für dein Feedback ❤️
# o_3c78nwPl0: Ich auch 😢😢
# o_3c78nwPl0: ❤️🙏💫
# o_3c78nwPl0: Immer noch deutlich angenehmer als diese ganzen ag
# o_3c78nwPl0: 😀❤️
# o_3c78nwPl0:  @petraschettler4289  sind trotzdem ziemlich unsex
# o_3c78nwPl0: Ne Andreas. Du nervst :D
# o_3c78nwPl0: Die treiben einen in den Wahnsinn,  ja. Nervig.
# o_3c78nwPl0: Lieber Andreas, so habe ich auch mal gedacht bzw.
# lc7W_VLAWQM: ♥️
# Z02YMn1plPk: Ich freu mich immer auf jedes Video
# Z02YMn1plPk: Bei mir war es andersherum, bin vom Boreout in den
# Z02YMn1plPk: ♥️ Vielen Dank für die Beantwortung meiner Frage❤️
# Z02YMn1plPk: Sehr gut erklärt. Vielen lieben Dank und Entschuld
# Z02YMn1plPk: WAS FÜR ein VIDEO DANKE 🙏
# Z02YMn1plPk: Den Begriff Boreout kannte ich noch nicht, gute In
# Z02YMn1plPk: Der Ausstieg aus dem Ganzen ist ein Überdenken der
# Z02YMn1plPk: Und was ist, wenn der Arbeitgeber einem Steine in
# Z02YMn1plPk: Vielen lieben Dank und schön, dass ich es offensic
# Z02YMn1plPk:  @DrMichaelaKrohn  😊♥️ Danke
# Z02YMn1plPk: Danke für deinen Kommentar😀❤💫
# Z02YMn1plPk: 🙂🙏💫
# 9A32RmNAGNo: Ich bin ein negativ self talker.
# Obwohl ich zwei A
# 9A32RmNAGNo: Einfühlsam und gut nachvollziehbar erklärt.. ich m
# 9A32RmNAGNo: Da hat die Frau Doktor mal kurz den Ärtzejargon "a
# 9A32RmNAGNo: So ist es. Danke.
# 9A32RmNAGNo: Hi, schönes Video. Genau zu dem Thema was mich int
# 9A32RmNAGNo: Gutes Video! Sollt mir vlt öfter mal vor Augen hal
# 9A32RmNAGNo: Bietest du aktuell Gruppencoachings an?
# 9A32RmNAGNo: Hallo ja ich bin wertvoll aber nur als Werkzeug da
# 9A32RmNAGNo: Wie schade ❤🤔
# 9A32RmNAGNo:  @DrMichaelaKrohn
# Finde ich auch.
# Aber diese Den
# 9A32RmNAGNo: Danke 😊🙏
# 9A32RmNAGNo: Weil du existierst, weil du da bist!
# 9A32RmNAGNo: Lieber Jörg,
# schade, dass du das so erlebst. Wie s
# cG9OLQ3hFQQ: Hallo, schönes Video. Ich bin eher so ein Prokrast
# cG9OLQ3hFQQ: ❤
# Sury-4yiQcg: Mir wurde von meiner Mutter verboten mich kindisch
# Sury-4yiQcg: Die Beispielsätze, die Sie erwähnt haben, habe ich
# Sury-4yiQcg: Vielen Dank für dieses Video. Den Buchtip "Giftige
# Sury-4yiQcg: Sehr guter Ansatz... Reflektieren ist so wertvoll
# Sury-4yiQcg: 👍
# Vielen Dank für Ihre hilfreichen Informationen!
# Sury-4yiQcg: Sehr gerne. Der Weg in die Selbstheilung ist natür
# G8eccc8Z1So: Ihr Lieben - mir ist gerade nochmal ganz wichtig z
# g4o_Tr3QfeY: Great Job Joey !!!
#
# You saved the BEST for Las
# g4o_Tr3QfeY: That's amazing! What happened to him?
# ZlKb7ivyqZc: Kezzie is absolutely beautiful, and a blessing<3
# ZlKb7ivyqZc: Heartwarming!
# ZlKb7ivyqZc: Omg I be only heard of one other Keziah so glad to
# o7fwIyqrcqE: Amazing. What a great brother and and wonderful fa
# o7fwIyqrcqE: i have the privilege of knowing kevin's mom, cindy
# o7fwIyqrcqE: Just cant believe my accident was so similar to th
# o7fwIyqrcqE: God has "Gloriously" saved you for such a time as
# o7fwIyqrcqE: there is so much crap on youtube that noone should
# o7fwIyqrcqE: I'm praying for you
# o7fwIyqrcqE: i feel sorry for kevin :(
# o7fwIyqrcqE: Thanks to Grandpa Bob Clancy for telling us about
# o7fwIyqrcqE: Those inflatables are darn dangerous. My nephew wa
# o7fwIyqrcqE: I'm glad that your good now🌸
# o7fwIyqrcqE: Glory to God bro!
# o7fwIyqrcqE: +Sino Wow when I was little I split my eye brow op
# IJgNxEDCp2Q: I couldnt leave either what an amazing lil man and
# IJgNxEDCp2Q: Go Aiden, I miss working with you kiddo!
# atEAeuHTLa8: @theartofbone Match rate for 2010 was 93% first ro
# -ql4mo4emY8: I hope that doctor wasnt saved and is 6 feet under
# -ql4mo4emY8: Only if saw x the movie existed for corrupt and gr
# x3wODOddN0E: Touching story, I'm so glad to hear that she made
# x3wODOddN0E: Aww poor kiana I'm so glad too see you recover!
# x3wODOddN0E: @birds16ful she was 12 and she did recover.
# x3wODOddN0E: omg u go girl!
# x3wODOddN0E: how is she doing now that it's been several years?
# n-Okladnsag: Aww she's so cute! I just want to snuggle her!
# Qa8QWSgHuYw: he is a precious gift from GOD. so happy for all o
# Qa8QWSgHuYw: Aw my gosh, he's too precious for words! What a li
# iTQ9p--0lJw: Well bless your hearts! God is so gooood and has b
# iTQ9p--0lJw: SHE WAS BORN ON MY BIRTH DAY!!!!!!!!!!!!!!!!!!
# jlXeOfWGzXw: Some illnesses r so very cruel what an awesome lil
# jlXeOfWGzXw: such a brave girl, God bless your beautiful family
# jlXeOfWGzXw: she is very pretty.
# KT5_o29YQIg: Such a wonderful family, I wish she gets better, a
# KT5_o29YQIg: she is an amazingly beautiful brave little girl! i
# KT5_o29YQIg: she is so cute!
# KT5_o29YQIg: Go Emma!
# KT5_o29YQIg: Vampiretk an lil emma i wish u luck xx
# KT5_o29YQIg: How is she doing now?
# FexVeo2R-tE: Thank you very much, working together is the best.
# xeL2BeRG5CQ: good show
# MxSQ5AcsA-0: Gavin's life is lucky
# PDYgQMYT2PQ: Der Prof. hat das bei mir gemacht, super sage ich,
# h5JvA4m1kQQ: Auch ich bin gerade bei Dr Jan Vögele in Behandlun
# 74mGPeOGsAM: Ich trage wegen meiner Inkontinenz Windeln und kom
# JtRGycORnX8: Sehr gut erklärt
# RWq9DoQHA_Y: 🇦🇱🇩🇪
# tmL16GWoUEU: Guten  Tag machen ihr auch ein trichterbrust impla
# tmL16GWoUEU: Wird die Metallstange auf einer Seite fixiert oder
# tmL16GWoUEU: Hallo
# @user-so7nt9rx8q, die von uns eingebrachte
# Vg8kLQNattQ: Hallo, wieso geht dem So2 Werte geht nach unten no
# Vg8kLQNattQ: Habe copd und bin auf Suche nach Lösungen aber Lat
# Vg8kLQNattQ: Hallo, diese Aufzeichnung eines Online-Fachsymposi
# jnxpIGYmmg8: Sorry.Ich bekomme 2 Jahre Ocrevus und wenn ich die
# jnxpIGYmmg8: Ich habe auch MS & möchte mir kein neuartigen mRNA
# oHf94BC9KJ8: Hallo zusammen,
# Bei mir steht eventuell exakt dies
# oHf94BC9KJ8: Hallo,
#
# bei Fragen oder Bedenken vor der OP könne
# qn542vYCJtg: 👍🏻 und weiter viel Erfolg für die Ausbildung!
# GaCgli7jThY: Viel Erfolg weiterhin 👍👏🏆
# GaCgli7jThY: Starkes Statement! Wir wünschen Herrn Ebeling weit
# geAb_MASUU0: Beginnen Sie liebe Melissa Spiegel in dem Krankenh
# mIUwBWeCCio: Vor dieser Arbeit kann man nur seinen Hut ziehen.
# mIUwBWeCCio: hatte diesen OP am 06.09.2012. Da ich einen Lungen
# mIUwBWeCCio: 👏👏👏
# E5_rfCMbgvM: Genial, danke euch!
# 2D9Hkgk92Q8: Ouch! 😳
# 2D9Hkgk92Q8: Urolift procedure has COMPLETELY PERMANENTLY DESTR
# 2D9Hkgk92Q8: Did u have it done in the U.S?
# 2D9Hkgk92Q8:  @dl4511  - "Did it hurt?" is a better question ;+
# 2D9Hkgk92Q8:  @drogoferrari5283  Not really much pain at all.
# 2D9Hkgk92Q8: Thanks for the information god bless you !! This i
# 2D9Hkgk92Q8: Dear All doctors respected,
#
# Kindly please mentio
# 2D9Hkgk92Q8: Dear All doctors respected,
#
# Kindly please mentio
# Cca_kTr-2bc: Prof. Dr. Lahme ist in meinen Augen der Spezialist
# q_FxB_6bKqA: Danke sehr hilfreich :))
# JyYjMyrGR_M: Unglaublich was Ärzte so leisten , mein Dank an di
# JyYjMyrGR_M: Es wäre schöner wenn der Arzt genauer beschreiben
# JyYjMyrGR_M: Krass wie die sich da zurechtfinden.
# JyYjMyrGR_M: Lieber in der Türkei Opieren.... In Deutschland OP
# JyYjMyrGR_M: Ja dann mach mal ;-)
# JyYjMyrGR_M: Nirgendwo ist die Garantie 100% aber in Deutschlan
# SXqnxd0QWQ4: Echt absolut beeindruckend die Neoblase im Situs z
# SXqnxd0QWQ4: baaaahhh wer lädt sowas hoch?!! xD
# Q6dBGPAsdbE: R message
# FrOXJznjiGE: leider nicht informativ, tut mir leid für die schl
# dyH_A85AuzQ: Vielen Dank für diese tollen Filmmaterialien
# UEVqBEfxKvk: 😂Ein so Guter  Perfekter Arzt ist selten  Herr Egn
# sSrb_iT0TwI: Warum fehlt in der Statistik über Berufsgruppen di
# sSrb_iT0TwI: Kann man das zusammenfassen mit zuviel wechselnder
# sSrb_iT0TwI: In dem Video werden mehrere Statistiken vorgestell
# nkbQ4uBjgKU: Ohne Krankheitseinsicht wird eine Behandlung schwe
# nkbQ4uBjgKU: Es geht doch eh nur um Medikamente, die kann man a
# SleoknJtpeI: Hallo , man braucht eine Aufgabe , damit sich das
# SleoknJtpeI: Rosi, die Dosis macht das Gift.
# SleoknJtpeI: Er hat Recht. Hab schon  in der Jugeand gelernt, w
# SleoknJtpeI: Kritische Kommentare werden gelöscht?  Diskussione
# SleoknJtpeI: Das ist eine sehr gute Aufklärung über die Alkohol
# SleoknJtpeI: Wirklich ein sehr guter Vortrag. Die Zusammenhänge
# SleoknJtpeI: Ein sehr interessanter Vortrag. Auch die Art des V
# SleoknJtpeI: Gut erklärt und gut vorgetragen! Danke!
# SleoknJtpeI: Ein toller Vortrag und ich mag seinen Humor :-D
# SleoknJtpeI: Ich denke, es ist das wichtigste Werkzeug, erst ei
# SleoknJtpeI: Guten Tag, ich wollte mal fragen, ob der Vortrag v
# SleoknJtpeI: Guten Abend .... Wie kommt es , das immer wieder v
# SleoknJtpeI: Ringo star ist endlich trocken😮
# SleoknJtpeI: Vielen Dank für das Video!!!
# Leider viel zu wenig
# SleoknJtpeI: Leider ist das so. Wer nicht will wird in jedem Fa
# SleoknJtpeI: Völlig richtig
# SleoknJtpeI: Das stimmt, rein technisch gesehen. Der Weg dahin
# SleoknJtpeI:  @b.b.b81  mit Disziplin schafft man alles.
# SleoknJtpeI: Das ist leider nicht so einfach aber hört sich an
# SleoknJtpeI:  @tea_earl-grey-hot  Dazu verweise ich auf Gaby Gu
# SleoknJtpeI: Eine Aufgabe ist ein Pfeiler von vielen, der einen
# SleoknJtpeI: Da wir nicht wissen, worauf Sie sich beziehen, kön
# SleoknJtpeI: @Iron Freddy Auch hier wissen wir nicht, worauf Si
# SleoknJtpeI: Vielen Dank für Ihre positive Rückmeldung!
# SleoknJtpeI: Herzlichen Dank für das positive Feedback!
# SleoknJtpeI: Vielen Dank dafür. Über das Lob wurde sich natürli
# SleoknJtpeI: Vielen Dank für das positive Feedback!
# SleoknJtpeI: mir auch
# SleoknJtpeI: Hallo Bumblebee Bee,
#
# vielen Dank für deinen Komme
# SleoknJtpeI: Bei einer Sucht handelt es sich aus unserer Sicht
# SleoknJtpeI:  @LVRKlinikLangenfeld  Vielen Herzlichen Dank für
# SleoknJtpeI: Hallo Herr Grigolait, sis kennen mich 😂Kimberly Do
# SleoknJtpeI: 1a!
# SleoknJtpeI: Einfach Iboga einnehmen!!!
# SleoknJtpeI: Meines Erachtens gibt es nur ein Grund der Alkohol
# SleoknJtpeI: Sie reden sehr wohl gendergerecht, da Sie das gene
# SleoknJtpeI: Hallo Frau Donnelly, vielen Dank für Ihren Komment
# SleoknJtpeI: Wir unterscheiden zwischen der Definition einer Su
# SleoknJtpeI:  @LVRKlinikLangenfeld  ich bleibe bei meiner Meinu
# SleoknJtpeI: Es werden in dem Vortrag andere Themen beleuchtet
# NqTqfDntRwg: Erster!
# NqTqfDntRwg: Ich bin Frau ögut kubra ogut muta.ich tahte meinen
# NqTqfDntRwg: Alls transfrau Türke von Frau Doktor erklärt was 9
# NqTqfDntRwg: Danke für deinen Kommentar :)
# NqTqfDntRwg: Guten Tag Frau Ogut,
#
# leider bin ich nicht sicher,
# X17laWOjP8k: Super !
# X17laWOjP8k: Top :)
# X17laWOjP8k: Anni♡
# tJ-JfmHBf90: 🤔
# ZVPoqIQZZGI: Was wird hier eig. verkauft? Die Realität, die ich
# vGoo6dUsJUA: Ihr seid die besten ihr hab meine Speiche gerätet
# vGoo6dUsJUA: Ein sehr gutes Klinikum
# vGoo6dUsJUA: Sie tuhen oft nur so,wir sind die besten..
# vGoo6dUsJUA: Klinikum kann ich nicht empfehlen! Professionalitä
# vGoo6dUsJUA: Das schlechteste Klinikum .Mein Opa war da weil er
# vGoo6dUsJUA: So eine negative Erfahrung habe ich auch gemacht!
# UxzY6evJqQE: Dieses Video ist sehr hilfreich für mich. Für mich
# XKVXnT6EbEc: 11:03 - 11:33 de facto heißt, eine Vollnarkose kan
# FdqD7tfqpQI: Voll überzogener Beitrag. Als ob jeder sein Kind g
# FdqD7tfqpQI: Moin, gibt's dafür eine Begründung? Dann würde es
# H8Aa2TG3T0U: Ist das der PAE überlegen?
# H8Aa2TG3T0U: Rezum als Alternative eher besser oder eher schlec
# H8Aa2TG3T0U: Hallo tom tom, die Methoden sind nicht vergleichba
# 3YbPqZeFiV4: dieser tobias ist lit af
# 3YbPqZeFiV4: Degah😂😂😂😂😂
# 3YbPqZeFiV4: Tobi gibs ihr

# %%
scraping.get_video_infos()
# Out:
# > Querying video ids from upload playlists from YouTube Data API (Warning: cost=1/channel)
#   0%|          | 0/3777 [00:00<?, ?it/s]

# %%
scraping.videos["lCSVPS0PLS8"]
# Out:
# {'channel_name': '@PennStateHealth',
#  'description': 'http://pennstatehershey.org  Do you own your own pool? Or maybe one of those inflatable toddler pools? Summertime is a great time to have fun in the water.\nBut a small child can drown in as little as one inch of water. Supervision of your children is very important when around pools.\n\nWhether you have an in-ground or above ground pool, consider that you need four sided fencing. Your home is not that fourth side. Install a door or floating pool alarm.\nWater wings, noodles, those are for fun. They are not personal flotation devices, which need to be fitted properly.\n\nFinally, that rigid or inflatable toddler pool -- empty those every day, every time.\nAlso for in-ground pools, check your drains. A missing or flat drain cover can suck a child down to the bottom and hold them there.\n\nFor more tips to keep your family safe around pools, go to pennstatehershey.org and click on Project Health.',
#  'transcription': "Do you own your own pool?Or maybe one of those inflatable toddler pools?We'll give you some pool safety tips on this\nProject Health.Summertime is a great time to have fun in\nthe water.But a small child can drown in as little as\none inch of water.Supervision of your children is very important\nwhen around pools.Whether you have an in-ground or above ground\npool, consider that you need four sided fencing.Your home is not that fourth side.Install a door or floating pool alarm.Water wings, noodles, those are for fun.They are not personal flotation devices, which\nneed to be fitted properly.Finally, that rigid or inflatable toddler\npool -- empty those every day, every time.Also for in-ground pools, check your drains.A missing or flat drain cover can suck a child\ndown to the bottom and hold them there.For more tips to keep your family safe around\npools, go to pennstatehershey dot org andclick on Project Health.",
#  'no_comments': True,
#  'title': 'Pool safety tips for summertime - Penn State Hershey',
#  'tags': ['pool safety',
#   'water safety',
#   'pool',
#   'penn state hershey',
#   'hershey medical center',
#   'penn state',
#   'Penn State Hershey Medical Center (Hospital)',
#   'swimming']}
